# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'date':['2021-03-01 01:01:01','2021-03-02 01:01:01','2021-03-03 01:01:01',
                           '2021-03-04 01:01:01','2021-03-05 01:01:01'], 
                   'outcome':[2,1,2,3,2]})
df
# Out:
#                   date  outcome
# 0  2021-03-01 01:01:01        2
# 1  2021-03-02 01:01:01        1
# 2  2021-03-03 01:01:01        2
# 3  2021-03-04 01:01:01        3
# 4  2021-03-05 01:01:01        2

# %%
df = df.set_index('date')

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
pd.to_datetime(df.date)
# Out:
# 0   2021-03-01 01:01:01
# 1   2021-03-02 01:01:01
# 2   2021-03-03 01:01:01
# 3   2021-03-04 01:01:01
# 4   2021-03-05 01:01:01
# Name: date, dtype: datetime64[ns]

# %%
date = pd.to_datetime(pd.Series(['2021-03-01 01:01:01','2021-03-02 01:01:01','2021-03-03 01:01:01','2021-03-04 01:01:01','2021-03-05 01:01:01']))
outcome = pd.Series([2,1,2,3,2])

# %%
import visualize

# %%
visualize.time_delta(date, outcome)

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(pd.to_datetime('2021-01-01 01:00:00'))
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
datetime = pd.to_datetime(np.array(['2021-01-01','2021-01-02']))
datetime.year
# Out:
# Int64Index([2021, 2021], dtype='int64')

# %%
series = pd.Series(['2021-01-01','2021-01-02'])
np.array(series)
# Out:
# array(['2021-01-01', '2021-01-02'], dtype=object)
